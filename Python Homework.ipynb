# %%
from fourier import fourier_plot

# %%
# %matplotlib inline

# %%
fourier_plot()

# %%
from henon import HenonPlot

# %%
HenonPlot()

# %%
from henon import HenonPlot2

# %%
HenonPlot2(200, 1.03)
